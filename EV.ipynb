# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukul1Panwar/Machine_Learning/blob/main/EV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import numpy as np
import bs4
from bs4 import BeautifulSoup

# %%
web = "https://www.cars24.com/new-cars/kia/"

# %%
response = requests.get(web)

# %%
print("web status : ",response)
# Out:
# web status :  <Response [200]>

# %%
soup = BeautifulSoup(response.content,"html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link as="image" fetchpriority="high" href="https://static-cdn.cars24.com/prod/new-car-cms/root/2025/03/17/621823d8-2e99-48e6-bd14-87c71ce8ee9d-make-hero.webp" rel="preload"/><link as="image" fetchpriority="high" href="https://static-cdn.cars24.com/prod/new-car-cms/Kia/Sonet/2024/08/20/2d0baeae-d433-446d-8d5a-ef2196d9c66e-Sonet.jpg?w=300&amp;dpr=3&amp;optimize=low&amp;format=auto&amp;quality=50" rel="preload"/><link as="image" fetchpriority="high" href="https://static-cdn.cars24.com/prod/new-car-cms/Kia/Seltos/2024/08/20/ab88f9c8-e5dd-49a9-8104-bebc2dd9f70c-seltos.jpg?w=300&amp;dpr=3&amp;optimize=low&amp;format=auto&amp;quality=50" rel="preload"/><link as="image" fetchpriority="high" href="https://static-cdn.cars24.com/prod/new-car-cms/Kia/Syros/2024/12/20/478f865d-8235-4f1c-a79e-7cedfc6caca6-Untitled-design-_1_.png?w=300&amp;dpr=3&amp;optimize=low&amp;format=auto&amp;quality=50" rel="preload"/><link as="image" fetchpriority="high" href="https://static-cdn.cars24.com/prod/new-car-cms/Kia/EV-9/2024/04/17/cfb92148-bea2-488e-8ee0-6a1fa628ba1f-Kia_EV9_CarImage.jpg?w=300&amp;dpr=3&amp;optimize=low&amp;format=auto&amp;quality=50" rel="preload"/><link as="image" fetchpriority="high" href="https://static-cdn.cars24.com/prod/new-car-cms/Kia/Carens-Clavis/2025/05/08/df937efd-8002-4cce-b4c4-fb8a16eb1347-Clavis-Feature-Image-1440x645.jpg?w=300&amp;dpr=3&amp;optimize=low&amp;format=auto&amp;quality=50" rel="preload"/><link data-precedence="next" href="https://assets.cars24.com/production/new-auto/250918164026/_next/static/css/3f69f2ef58cf9cea.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/new-auto/250918164026/_next/static/css/0a434b21b90b8e95.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/new-auto/250918164026/_next/static/css/c9619780b294bc48.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/new-auto/250918164026/_next/static/css/687e2ba80f6d5ebd.css" rel="stylesheet"/><link data-precedence="next" href="https://assets.cars24.com/production/new-auto/250918164026/_next/static/css/925975425df0cdc2.css" rel="stylesheet"/><link as="script" fetchpriority="low" href="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/webpack-d4c7d1fa870b1856.js" rel="preload"/><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/fd9d1056-43602e934f0e50de.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/7023-b0970fa1862a6a98.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/main-app-55bbd77d79f9187f.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/9036-b6c1c044909e0612.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/5223-304d4f4aa6a5a970.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/9183-2b34e4278e59d130.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/3242-2011ab40bd7a8646.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/7415-e188090f295003ba.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/4862-dec5da50959667bd.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/app/layout-4e5964ee28d8c6ba.js"></script><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/5859-8bba99f5dc86b45e.js"></script><script async="" src="http ...
#   "@context": "https://schema.org",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
#     {
#       "@type": "ListItem",
#       "position": 1,
#       "name": "Home",
#       "item": "https://www.cars24.com/"
#     },
#     {
#       "@type": "ListItem",
#       "position": 2,
#       "name": "New Cars",
#       "item": "https://www.cars24.com/new-cars/"
#     },
#     {
#       "@type": "ListItem",
#       "position": 3,
#       "name": "Kia"
#    }
#   ]
# }</script><script id="json-ld-1" type="application/ld+json">{
#   "@context": "https://schema.org",
#   "@type": "Car",
#   "brand": "Kia",
#   "url": "https://www.cars24.com/new-cars/kia/"
# }</script><script id="json-ld-2" type="application/ld+json">{
# "@context": "http://schema.org",
# "@type": "WebPage",
# "Url": "https://www.cars24.com/new-cars/kia/"
#  }</script><header class="bg-primary h-14 md:h-16 w-full px-4 lg:px-12 items-center flex justify-between top-0 left-0 right-0 z-40 py-2 lg:py-3 sticky"><div class="flex gap-4"><a aria-label="Back to homepage" class="flex items-center md:h-8 w-auto h-[26px]" href="/new-cars/" variant="dark"><img alt="Cars24 Logo" class="md:h-8 w-auto h-[26px]" data-nimg="1" decoding="async" height="80" loading="lazy" src="https://cdn.cars24.com/qa/bikes/2025/06/02/Logo_CARS24-3f151795-16a1-42b7-aea9-7d59012027e4.svg" style="color:transparent" width="120"/></a></div><nav class="hidden lg:flex justify-center items-center gap-8 font-medium text-sm text-[#b0b0b0] data-[active=true]:text-white"><div class="w-fit h-fit relative flex justify-center"><button class="group flex gap-2 items-center justify-center font-normal text-[#b0b0b0] data-[active=true]:text-white" data-active="false">New Cars<svg class="w-4 h-4 group-data-[active=true]:rotate-180 transition-transform" fill="none" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><g id="vuesax/bold/arrow-down"><g id="arrow-down"><path d="M14.9333 6.81667H9.74167H5.06667C4.26667 6.81667 3.86667 7.78333 4.43334 8.35L8.75 12.6667C9.44167 13.3583 10.5667 13.3583 11.2583 12.6667L12.9 11.025L15.575 8.35C16.1333 7.78333 15.7333 6.81667 14.9333 6.81667Z" fill="currentColor" id="Vector" stroke="currentColor"></path></g></g></svg></button><!--$--><div class="min-w-fit h-fit absolute z-50 transition-all top-[100%] left-0 bg-transparent" hidden=""><div class="w-max h-max max-h-[85vh] grid grid-cols-3 bg-white text-black rounded-2xl p-5 gap-6 shadow-[10px_30px_150px_rgba(46,38,92,0.25)] mt-8 overflow-y-auto min-w-[340px]"><div class="flex flex-col row-span-2"><div class="col-span-3"></div><a class="px-3 py-2 font-light text-sm flex justify-between items-center bg-gradient-to-r md:hover:from-skyBlue md:hover:font-medium text-cornflowerBlue" href="https://www.cars24.com/new-cars/" target="_blank"><span>Explore new cars</span><svg class="min-w-4 min-h-4 w-4 h-4 ml-2" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7 17L17 7m0 0H7m10 0v10" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></svg></a><a class="px-3 py-2 font-light text-sm flex justify-between items-center bg-gradient-to-r md:hover:from-skyBlue md:hover:font-medium text-cornflowerBlue" href="https://www.cars24.com/new-cars/compare-cars/" target="_blank"><span>Compare</span><svg class="min-w-4 min-h-4 w-4 h-4 ml-2" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7 17L17 7m0 0H7m10 0v10" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></svg></a><a class="px-3 py-2 font-light text-sm flex justify-between items-center bg-gradient-to-r md:hover:from-skyBlue md:hover:font-medium text-cornflowerBlue" href="https://www.cars24.com/new-cars/search-by/all-cars/" target="_blank"><span>All cars</span><svg class="min-w-4 min-h-4 w-4 h-4 ml-2" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7 17L17 7m0 0H7m10 0v10" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></svg></a><a class="px-3 py-2 font-light text-sm flex justify-between items-center bg-gradient-to-r md:hover:from-skyBlue md:hover:font-medium text-cornflowerBlue" href="https://www.cars24.com/new-cars/search-by/upcoming-cars/" target="_blank"><span>Upcoming Cars</span><svg class="min-w-4 min-h-4 w-4 h-4 ml-2" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7 17L17 7m0 0H7m10 0v10" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></svg></a><a class="px-3 py-2 font-light text-sm flex justify-between items-center bg-gradient-to-r md:hover:from-skyBlue md:hover:font-medium text-cornflowerBlue" href="h ...
# </div></div><div><h3>Which Kia gets the best mileage?</h3><div>The Kia Sonet is often said to be the best mileage Kia car in India. Specifically, the diesel manual variant of the Sonet is reported to have a mileage of up to 24.1 kmpl.
# </div></div><div><h3>Is Kia a trusted car brand?</h3><div>Kia has built trust through its modern design, advanced features, good customer services, and a fast-growing service network. All these factors have helped the carmaker established itself well in our market.
# </div></div></div><button class="rounded-lg flex justify-center items-center gap-2 font-semibold md:leading-tight min-w-[148px] px-4 py-3 text-sm bg-secondary text-primary md:hover:bg-mercury w-full mt-[22px] lg:py-2.5 lg:text-base lg:w-fit"><span class="flex items-center" data-test-id="faq-button">Expand all </span><svg class="h-4 w-4 shrink-0 transition-transform duration-200" fill="none" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><g id="vuesax/bold/arrow-down"><g id="arrow-down"><path d="M14.9333 6.81667H9.74167H5.06667C4.26667 6.81667 3.86667 7.78333 4.43334 8.35L8.75 12.6667C9.44167 13.3583 10.5667 13.3583 11.2583 12.6667L12.9 11.025L15.575 8.35C16.1333 7.78333 15.7333 6.81667 14.9333 6.81667Z" fill="currentColor" id="Vector" stroke="currentColor"></path></g></g></svg></button></div></section></section><div class="bg-drWhite border-b border-b-silverMedal"><section class="mx-auto px-4 max-w-[1440px] py-0 md:py-0 md:px-4 lg:px-10 xl:px-20" data-test-id="breadcrumbs-section"><nav aria-label="breadcrumb" class="w-full bg-drWhite"><ol class="flex h-[14px] md:h-4 py-5 md:py-8 gap-2"><li class="group flex md:gap-1 gap-[2px] items-center justify-center md:text-sm text-xs md:leading-4 leading-[14px]"><a class="group-last:text-nickel text-primary group-last:pointer-events-none group-last:line-clamp-1 text-nowrap group-last:text-wrap" data-test-id="breadcrumb-item-0" href="https://www.cars24.com/">Home<span class="group-last:hidden text-nickel"> /</span></a></li><li class="group flex md:gap-1 gap-[2px] items-center justify-center md:text-sm text-xs md:leading-4 leading-[14px]"><a class="group-last:text-nickel text-primary group-last:pointer-events-none group-last:line-clamp-1 text-nowrap group-last:text-wrap" data-test-id="breadcrumb-item-1" href="https://www.cars24.com/new-cars/"> New Cars<span class="group-last:hidden text-nickel"> /</span></a></li><li class="group flex md:gap-1 gap-[2px] items-center justify-center md:text-sm text-xs md:leading-4 leading-[14px]"><a class="group-last:text-nickel text-primary group-last:pointer-events-none group-last:line-clamp-1 text-nowrap group-last:text-wrap" data-test-id="breadcrumb-item-2" href="https://www.cars24.com/new-cars/kia/">Kia<span class="group-last:hidden text-nickel"> /</span></a></li></ol></nav></section></div><!--$!--><template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING"></template><!--/$--><!--$!--><template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING"></template><!--/$--><div id="portal"></div><!--$!--><template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING"></template><!--/$--><!--$!--><template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING"></template><!--/$--><!--$!--><template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING"></template><!--/$--><!--$!--><template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING"></template><!--/$--><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P3C9RJ" style="display: none; visibility: hidden;" width="0"></iframe></noscript><script async="" src="https://assets.cars24.com/production/new-auto/250918164026/_next/static/chunks/webpack-d4c7d1fa870b1856.js"></script><script>(self.__next_f=self.__next_f||[]).push([0]);self.__next_f.push([2,null])</script><script>self.__next_f.push([1,"1:HL[\"https://assets.cars24.com/production/new-auto/250918164026/_next/static/media/1a2c1f6950f0c99e-s.p.ttf\",\"font\",{\"crossOrigin\":\"\",\"type\":\"font/ttf\"}]\n2:HL[\"https://assets.cars24.com/production/new-auto/250918164026/_next/static/media/e4af272ccee01ff0-s.p.woff2\",\"font\",{\"crossOrigin\":\"\",\"type\":\"font/woff2\"}]\n3:HL[\"https://assets.cars24.com/production/new-auto/250918164026/_next/static/css/3f69f2ef58cf9cea.css\",\"style\"]\n4:HL[\"https://assets.cars24.com/production/new-auto/250918164026/_next/static/css/0a434b21b90b8e95.css\",\"style\"]\n5:HL[\"https://assets.cars24.com/production/new-auto/250918164026/_next/static/css/c9619780b294bc48.css\",\"style\"]\n6:HL[\"https://assets.ca ...

# %%
results = soup.find_all("div",{'class':"relative flex flex-col lg:w-[calc(100%-300px)] md:order-1 lg:order-2 justify-between cursor-pointer"})

# %%
len(results)
# Out:
# 18

# %%
results[0]
# Out:
# <div class="relative flex flex-col lg:w-[calc(100%-300px)] md:order-1 lg:order-2 justify-between cursor-pointer"><a aria-label="View details of Kia Sonet" class="absolute inset-0 z-[1]" data-event-el-id="1342" data-event-make-name="Kia" data-event-model-name="Sonet" href="/new-cars/kia/sonet/"></a> <div class="flex justify-between items-center mx-4 lg:mx-0 mb-3 lg:mb-0"><h3 class="flex flex-col"><span class="text-xs md:text-sm whitespace-nowrap mb-1 text-darkGrey leading-4 md:leading-[14px] break-words font-medium">Kia </span><span class="md:leading-[26px] !leading-[26px] break-words text-lg md:text-lg font-medium text-primary">Sonet</span></h3><div class="flex flex-col items-end"><span class="font-semibold text-primary md:text-lg md:leading-[26px] mb-1 !leading-[26px] text-lg break-words">₹8.00L - 15.77L</span><span class="font-normal md:text-sm md:leading-4 whitespace-nowrap text-xs text-darkGrey !leading-[14px] break-words">Ex-showroom</span></div></div><div class="relative lg:hidden"><!--$!--><template data-dgst="BAILOUT_TO_CLIENT_SIDE_RENDERING"></template><div class="w-full md:h-[184px] [@media(min-width:1024px)]:w-[420px] [@media(min-width:1024px)]:h-[241px] [@media(min-width:1220px)]:w-[395px] [@media(min-width:1220px)]:h-[241px] aspect-video overflow-hidden"></div><!--/$--></div><div class="flex justify-between mt-3 lg:mt-2.5 gap-0 lg:gap-5"><div class="flex flex-col items-center lg:items-start w-1/3 border-r border-gray-300"><span class="font-medium text-primary md:text-sm text-sm truncate max-w-[100px] [@media(min-width:375px)]:max-w-[114px] leading-tight">250 Nm</span><span class="font-normal text-nickel md:text-sm md:leading-4 whitespace-nowrap text-xs truncate max-w-[100px] [@media(min-width:375px)]:max-w-[114px] leading-[14px]">Max Torque</span></div><div class="flex flex-col items-center lg:items-start w-1/3 border-r border-gray-300"><span class="font-medium text-primary md:text-sm text-sm truncate max-w-[100px] [@media(min-width:375px)]:max-w-[114px] leading-tight">SUV </span><span class="font-normal text-nickel md:text-sm md:leading-4 whitespace-nowrap text-xs truncate max-w-[100px] [@media(min-width:375px)]:max-w-[114px] leading-[14px]">Body Type</span></div><div class="flex flex-col items-center lg:items-start w-1/3"><span class="font-medium text-primary md:text-sm text-sm truncate max-w-[100px] [@media(min-width:375px)]:max-w-[114px] leading-tight">5 </span><span class="font-normal text-nickel md:text-sm md:leading-4 whitespace-nowrap text-xs truncate max-w-[100px] [@media(min-width:375px)]:max-w-[114px] leading-[14px]">Seating Capacity</span></div></div><ul class="text-gray-600 text-sm px-4 lg:px-0 mb-2 lg:mb-3 mt-4 lg:mt-3"><li class="mb-2 md:mb-1.5"><div class="flex gap-1.5 items-center"><svg class="w-[14px] h-[14px] lg:w-4 lg:h-4 text-[#daf5f3]" color="#0c6a64" fill="none" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M10 1.875A8.125 8.125 0 1018.125 10 8.133 8.133 0 0010 1.875z" fill="currentColor"></path><path d="M13.567 8.567l-4.375 4.375a.626.626 0 01-.884 0l-1.875-1.875a.625.625 0 11.884-.884l1.433 1.433 3.933-3.933a.626.626 0 01.884.884z" fill="#0c6a64"></path></svg><span class="font-normal md:text-xs text-darkGrey text-xs leading-[18px]">Feature-rich compact SUV</span></div></li><li class="mb-2 md:mb-1.5"><div class="flex gap-1.5 items-center"><svg class="w-[14px] h-[14px] lg:w-4 lg:h-4 text-[#daf5f3]" color="#0c6a64" fill="none" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M10 1.875A8.125 8.125 0 1018.125 10 8.133 8.133 0 0010 1.875z" fill="currentColor"></path><path d="M13.567 8.567l-4.375 4.375a.626.626 0 01-.884 0l-1.875-1.875a.625.625 0 11.884-.884l1.433 1.433 3.933-3.933a.626.626 0 01.884.884z" fill="#0c6a64"></path></svg><span class="font-normal md:text-xs text-darkGrey text-xs leading-[18px]">Stylish design</span></div></li><li class="mb-2 md:mb-1.5"><div class="flex gap-1.5 items-center"><svg class="w-[14 ...

# %%
#Torque
car_torque = results[0].find('span',{"class":"font-medium text-primary md:text-sm text-sm truncate max-w-[100px] [@media(min-width:375px)]:max-w-[114px] leading-tight"})
print(car_torque.text)
# Out:
# 250 Nm

# %%
# Car Brand
car_brand = results[0].find('a',{"class":"absolute inset-0 z-[1]"})['data-event-make-name']
print(car_brand)
# Out:
# Kia

# %%
# Price Type (ex-showroom)
price_type = results[0].find('span',{"class":"font-normal md:text-sm md:leading-4 whitespace-nowrap text-xs text-darkGrey !leading-[14px] break-words"})
print(price_type.text)
# Out:
# Ex-showroom

# %%
# car's url
car_url = results[0].find('a',{'class':'absolute inset-0 z-[1]'})['href']
print(car_url)
# Out:
# /new-cars/kia/sonet/

# %%
# sitting capacity
specs_div = results[0].find("div", {'class': "flex justify-between mt-3 lg:mt-2.5 gap-0 lg:gap-5"})
sitting_capacity_div = specs_div.find_all("div")[2] # third div (index starts at 0)
sitting_capacity = sitting_capacity_div.find("span")
print(sitting_capacity.text)
# Out:
# 5

# %%
# car body type
specs_div = results[5].find("div", {'class': "flex justify-between mt-3 lg:mt-2.5 gap-0 lg:gap-5"})
body_type_div = specs_div.find_all("div")[1] # second div (index starts at 0)

body_type = body_type_div.find("span")
print(body_type.text)
# Out:
# 8

# %%
# price range in ex-showroom
car_price = results[0].find('span',{'font-semibold text-primary md:text-lg md:leading-[26px] mb-1 !leading-[26px] text-lg break-words'})
print (car_price.text)
# Out:
# ₹8.00L - 15.77L

# %%
# car name
car_name = results[0].find('a',{'class':"absolute inset-0 z-[1]"})['data-event-model-name']
print(car_name)
# Out:
# Sonet

# %%
# location
location = soup.find('button',{'aria-label':"change city"}).find('p').text
print(location)
# Out:
# new-delhi

# %%
car_details = {
    'car_brand':[],
    'car_name': [],
    'car_price': [],
    "price_type":[],
    'location':[],
    "car's url":[]

}

# %%
for i in range(len(results)):

  cars = results[i].find('a',{'class':"absolute inset-0 z-[1]"})

  car_name = cars['data-event-model-name']
  car_details['car_name'].append(car_name)

  car_url = cars['href']
  car_details["car's url"].append(car_url)

  car_brand = cars["data-event-make-name"]
  car_details['car_brand'].append(car_brand)

  car_price = results[i].find('span',{"class":'font-semibold text-primary md:text-lg md:leading-[26px] mb-1 !leading-[26px] text-lg break-words'})
  car_price = car_price.get_text(strip=True) if car_price else None
  car_details['car_price'].append(car_price)

  location = soup.find('button',{'aria-label':"change city"}).find('p').get_text(strip=True)
  car_details['location'].append(location)

  price_type = results[i].find('span',{"class":"font-normal md:text-sm md:leading-4 whitespace-nowrap text-xs text-darkGrey !leading-[14px] break-words"})
  price_type = price_type.get_text(strip=True) if price_type else None
  car_details['price_type'].append(price_type)

# %%
car_details
# Out:
# {'car_brand': ['Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia',
#   'Kia'],
#  'car_name': ['Sonet',
#   'Carens',
#   'Seltos',
#   'Syros',
#   'Carnival',
#   'EV9',
#   'EV6',
#   'Carens Clavis',
#   'Carens Clavis EV',
#   'Sorento',
#   'EV3',
#   'Tasman',
#   'Seltos Facelift',
#   'Carens Facelift',
#   'Sportage',
#   'Stonic',
#   'Sonet 2020-2023',
#   'EV6 2022-2024'],
#  'car_price': ['₹8.00L - 15.77L',
#   '₹10.52L - 19.94L',
#   '₹10.90L - 20.56L',
#   '₹9.50L - 17.80L',
#   '₹63.91L',
#   '₹1.30Cr',
#   '₹65.97L',
#   '₹11.50L - 21.50L',
#   '₹17.99L - 24.49L',
#   '₹25L - 33L',
#   '₹30L - 37L',
#   '₹30L - 40L',
#   '₹12L - 22L',
#   '₹12L - 19L',
#   '₹25L - 30L',
#   '₹9L - 10L',
#   '₹7.79L - 14.89L',
#   '₹60.95L - 65.95L'],
#  'price_type': ['Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom',
#   'Ex-showroom'],
#  'location': ['new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi',
#   'new-delhi'],
#  "car's url": ['/new-cars/kia/sonet/',
#   '/new-cars/kia/carens/',
#   '/new-cars/kia/seltos/',
#   '/new-cars/kia/syros/',
#   '/new-cars/kia/carnival/',
#   '/new-cars/kia/ev9/',
#   '/new-cars/kia/ev6/',
#   '/new-cars/kia/carens-clavis/',
#   '/new-cars/kia/carens-clavis-ev/',
#   '/new-cars/kia/sorento/',
#   '/new-cars/kia/ev3/',
#   '/new-cars/kia/tasman/',
#   '/new-cars/kia/seltos-facelift/',
#   '/new-cars/kia/carens-facelift/',
#   '/new-cars/kia/sportage/',
#   '/new-cars/kia/stonic/',
#   '/new-cars/kia/sonet-2020-2023/',
#   '/new-cars/kia/ev6-2022-2024/']}

# %%
df = pd.DataFrame(car_details)
df.to_csv('car_details.csv',index=False,encoding='utf-8-sig')

# %%
df.shape
# Out:
# (18, 6)

# %%
with open('car_details.csv','r') as f:
  print(f)
# Out:
# <_io.TextIOWrapper name='car_details.csv' mode='r' encoding='utf-8'>
